# %% [markdown]
# ### Implementing Google Cloud VertexAI Pipeline

# %%
from google_cloud_pipeline_components.preview.llm import rlhf_pipeline
from kfp import compiler

# %%
RLHF_PIPELINE_PKG_PATH = "rlhf_pipeline.yaml"

compiler.Compiler().compile(
  pipeline_func=rlhf_pipeline,
  package_path=RLHF_PIPELINE_PKG_PATH
)

# %% [markdown]
# **Import Google Cloud Buckets - dataset to pipeline**

# %%
parameter_values = {
  "preference_dataset": "gs://vertex-ai/generative-ai/rlhf/text_small/summarize_from_feedback_tfds/comparisons/train/*.jsonl",
  "prompt_dataset": "gs://vertex-ai/generative-ai/rlhf/text_small/reddit_tfds/train/*.jsonl",
  "eval_dataset": "gs://vertex-ai/generative-ai/rlhf/text_small/reddit_tfds/val/*.jsonl"
}

# %% [markdown]
# **Set LLM Model Olamar-2-7b**

# %%
parameter_values.update({
  "large_model_reference": "llama-2-7b"
})

# %%
import math

PREF_DATASET_SIZE=3000
BATCH_SIZE=64
REWARD_STEPS_PER_EPOCH= math.ceil(PREF_DATASET_SIZE / BATCH_SIZE)

REWARD_NUM_EPOCHS=30
reward_model_train_steps = REWARD_STEPS_PER_EPOCH * REWARD_NUM_EPOCHS
reward_model_train_steps
# Out:
# 1410

# %%
PROMPT_DATASET_SIZE=2000
BATCH_SIZE = 64
RL_STEPS_PER_EPOCH = math.ceil(PROMPT_DATASET_SIZE / BATCH_SIZE)

RL_NUM_EPOCHS = 10
reinforcement_learning_train_steps = RL_STEPS_PER_EPOCH * RL_NUM_EPOCHS
reinforcement_learning_train_steps
# Out:
# 320

# %% [markdown]
# **Set training steps**

# %%
parameter_values.update({
  "reward_model_train_steps": reward_model_train_steps,
  "reinforcement_learning_train_steps": reinforcement_learning_train_steps, # results from the calculations above
})

# %% [markdown]
# **Set default coefficient**

# %%
parameter_values.update({
  "reward_model_learning_rate_multiplier": 1.0,
  "reinforcement_learning_rate_multiplier": 1.0,
  "kl_coeff": 0.1, # increased to reduce reward hacking
  "instruction": "Summarize in less than 50 words"
})

# %%
parameter_values
# Out:
# {'preference_dataset': 'gs://vertex-ai/generative-ai/rlhf/text_small/summarize_from_feedback_tfds/comparisons/train/*.jsonl',
#  'prompt_dataset': 'gs://vertex-ai/generative-ai/rlhf/text_small/reddit_tfds/train/*.jsonl',
#  'eval_dataset': 'gs://vertex-ai/generative-ai/rlhf/text_small/reddit_tfds/val/*.jsonl',
#  'large_model_reference': 'llama-2-7b',
#  'reward_model_train_steps': 1410,
#  'reinforcement_learning_train_steps': 320,
#  'reward_model_learning_rate_multiplier': 1.0,
#  'reinforcement_learning_rate_multiplier': 1.0,
#  'kl_coeff': 0.1,
#  'instruction': 'Summarize in less than 50 words'}

# %% [markdown]
# **Hook up with Google VertexAI**

# %%
from src.utils import authenticate
credentials, PROJECT_ID, STAGING_BUCKET = authenticate()

REGION = "europe-west4"
# Out:
# Authenticated with service account: rlhf-56@wide-memento-483018-g8.iam.gserviceaccount.com
# Project ID: wide-memento-483018-g8
# Staging bucket: gs://rlhf_buck

# %%
import google.cloud.aiplatform as aiplatfrom
aiplatfrom.init(project=PROJECT_ID, location=REGION, credentials=credentials)

# %%
RLHF_PIPELINE_PKG_PATH
# Out:
# 'rlhf_pipeline.yaml'

# %% [markdown]
# **Ready to publish pipline to VertexAI Job**

# %%
job = aiplatfrom.PipelineJob(
  display_name='LLM-RLHF-TUNING',
  pipeline_root=STAGING_BUCKET,
  template_path=RLHF_PIPELINE_PKG_PATH,
  parameter_values=parameter_values,
)

# %%
job.run()
# Out:
# Creating PipelineJob
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:75, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      74 try:
# ---> 75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/grpc/_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
#     281         wait_for_ready=wait_for_ready,
#     282         compression=compression,
#     283     )
#     284     return response
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/grpc/_interceptor.py:331, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     328 call = self._interceptor.intercept_unary_unary(
#     329     continuation, client_call_details, request
#     330 )
# --> 331 return call.result(), call
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/grpc/_channel.py:438, in _InactiveRpcError.result(self, timeout)
#     437 """See grpc.Future.result."""
# --> 438 raise self
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/grpc/_interceptor.py:314, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     313 try:
# --> 314     response, call = self._thunk(new_method).with_call(
#     315         request,
#     316         timeout=new_timeout,
#     317         metadata=new_metadata,
#     318         credentials=new_credentials,
#     319         wait_for_ready=new_wait_for_ready,
#     320         compression=new_compression,
#     321     )
#     322     return _UnaryOutcome(response, call)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/grpc/_channel.py:1180, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1177 state, call = self._blocking(
#    1178     request, timeout, metadata, credentials, wait_for_ready, compression
#    1179 )
# -> 1180 return _end_unary_response_blocking(state, call, True, None)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/grpc/_channel.py:996, in _end_unary_response_blocking(state, call, with_call, deadline)
#     995     return state.response
# --> 996 raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "You do not have permission to act as service_account: 1070904449492-compute@developer.gserviceaccount.com. (or it may not exist)."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:192.178.223.95:443 {grpc_status:3, grpc_message:"You do not have permission to act as service_account: 1070904449492-compute@developer.gserviceaccount.com. (or it may not exist)."}"
# >
#
# The above exception was the direct cause of the following exception:
#
# InvalidArgument                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 job.run()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/google/cloud/aiplatform/pipeline_jobs.py:334, in PipelineJob.run(self, service_account, network, reserved_ip_ranges, sync, create_request_timeout, enable_preflight_validations)
#     310 """Run this configured PipelineJob and monitor the job until completion.
#     311
#     312 Args:
#    (...)    330         Optional. Whether to enable preflight validations for the PipelineJob.
#     331 """
#     332 network = network or initializer.global_config.network
# --> 334 self._run(
#     335     service_account=service_account,
#     336     network=network,
#     337     reserved_ip_ranges=reserved_ip_ranges,
#     338     sync=sync,
#     339     create_request_timeout=create_request_timeout,
#     340     enable_preflight_validations=enable_preflight_validations,
#     341 )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/google/cloud/aiplatform/base.py:862, in optional_sync.<locals>.optional_run_in_thread.<locals>.wrapper(*args, **kwargs)
#     860     if self:
#     861         VertexAiResourceNounWithFutureManager.wait(self)
# --> 862     return method(*args, **kwargs)
#     864 # callbacks to call within the Future (in same Thread)
#     865 internal_callbacks = []
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/google/cloud/aiplatform/pipeline_jobs.py:374, in PipelineJob._run(self, service_account, network, reserved_ip_ranges, sync, create_request_timeout, enable_preflight_validations)
#     343 @base.optional_sync()
#     344 def _run(
#     345     self,
#    (...)    351     enable_preflight_validations: Optional[bool] = False,
#     352 ) -> None:
#     353     """Helper method to ensure network synchronization and to run
#     354     the configured PipelineJob and monitor the job until completion.
#     355
#    (...)    372             Optional. Whether to enable preflight validations for the PipelineJob.
#     373     """
# --> 374     self.submit(
#     375         service_account=service_account,
#     376         network=network,
#     377         reserved_ip_ranges=reserved_ip_ranges,
#     378         create_request_timeout=create_request_timeout,
#     379         enable_preflight_validations=enable_preflight_validations,
#     380     )
#     382     self._block_until_complete()
#     384     # AutoSxS view model evaluations
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/google/cloud/aiplatform/pipeline_jobs.py:512, in PipelineJob.submit(self, service_account, network, reserved_ip_ranges, create_request_timeout, experiment, enable_preflight_validations)
#     509     return formatted_errors
#     511 try:
# --> 512     self._gca_resource = self.api_client.create_pipeline_job(
#     513         parent=self._parent,
#     514         pipeline_job=self._gca_resource,
#     515         pipeline_job_id=self.job_id,
#     516         timeout=create_request_timeout,
#     517     )
#     518 except Exception as e:
#     519     preflight_validations_error_messages = extract_error_messages(str(e))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/google/cloud/aiplatform_v1/services/pipeline_service/client.py:1738, in PipelineServiceClient.create_pipeline_job(self, request, parent, pipeline_job, pipeline_job_id, retry, timeout, metadata)
#    1735 self._validate_universe_domain()
#    1737 # Send the request.
# -> 1738 response = rpc(
#    1739     request,
#    1740     retry=retry,
#    1741     timeout=timeout,
#    1742     metadata=metadata,
#    1743 )
#    1745 # Done; return the response.
#    1746 return response
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlhf-env/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# InvalidArgument: 400 You do not have permission to act as service_account: 1070904449492-compute@developer.gserviceaccount.com. (or it may not exist).
